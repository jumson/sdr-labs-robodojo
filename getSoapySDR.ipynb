# %%
# must have passwordless sudo enabled for this to work!
# as root : echo 'demo ALL=(ALL) NOPASSWD: ALL' >> /etc/sudoers
# !sudo apt update
# Out:
# Hit:1 http://us.archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://us.archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 http://us.archive.ubuntu.com/ubuntu bionic-backports InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 11 packages can be upgraded. Run 'apt list --upgradable' to see them.

# %%
# Using these instructions: https://github.com/pothosware/PothosCore/wiki/Ubuntu
# first you need this to add repositories:
# !sudo apt install -y software-properties-common 

#core framework and toolkits (required)
# !sudo add-apt-repository -y ppa:pothosware/framework

#support libraries for pothos (required)
# !sudo add-apt-repository -y ppa:pothosware/support

#supplies soapysdr, and drivers (required)
# !sudo add-apt-repository -y ppa:myriadrf/drivers
    
#needed when using usrp devices
# !sudo add-apt-repository -y ppa:ettusresearch/uhd

#always update after adding PPAs
# !sudo apt-get update
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cron dirmngr distro-info-data gir1.2-glib-2.0 gnupg gnupg-l10n gnupg-utils
#   gpg gpg-agent gpg-wks-client gpg-wks-server gpgconf gpgsm iso-codes
#   libapt-inst2.0 libassuan0 libgirepository-1.0-1 libksba8 libmpdec2 libnpth0
#   libpython3-stdlib libpython3.6-minimal libpython3.6-stdlib lsb-release
#   pinentry-curses powermgmt-base python-apt-common python3 python3-apt
#   python3-dbus python3-gi python3-minimal python3-software-properties
#   python3.6 python3.6-minimal unattended-upgrades
# Suggested packages:
#   anacron logrotate checksecurity exim4 | postfix | mail-transport-agent
#   dbus-user-session libpam-systemd pinentry-gnome3 tor parcimonie xloadimage
#   scdaemon isoquery lsb pinentry-doc python3-doc python3-tk python3-venv
#   python3-apt-dbg python-apt-doc python-dbus-doc python3-dbus-dbg
# ...

# %%
# install Pothos and toolkits:
# !sudo apt install -y pothos-all

#install bindings for python2
# !sudo apt install -y python-pothos

#or install bindings for python3
# !sudo apt install -y python3-pothos

#install development files for python blocks
# !sudo apt install -y pothos-python-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   graphviz libann0 libcdt5 libcgraph6 libdouble-conversion1 libevdev2
#   libgts-0.7-5 libgts-bin libgudev-1.0-0 libgvc6 libgvpr2 libinput-bin
#   libinput10 liblab-gamut1 libmtdev1 libmuparserx4.0.7 libpathplan4
#   libpocofoundation50 libpocojson50 libpoconet50 libpocoutil50 libpocoxml50
#   libportaudio2 libpothos0.6 libpothosplotterutils0.2.0
#   libpothosqtcolorpicker0 libqt5concurrent5 libqt5core5a libqt5dbus5
#   libqt5gui5 libqt5network5 libqt5opengl5 libqt5printsupport5 libqt5svg5
#   libqt5widgets5 libqwt-qt5-6 libspuce0.4-3 libwacom-bin libwacom-common
#   libwacom2 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-randr0
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xkb1
#   libxkbcommon-x11-0 pothos-flow pothos-modules-audio pothos-modules-blocks
# ...

# %%
# SDR runtime packages
#soapy sdr runtime and utilities
# !sudo apt-get install -y soapysdr-tools

#python language bindings
# !sudo apt-get install -y python-soapysdr python-numpy

#python3 language bindings
# !sudo apt-get install -y python3-soapysdr python3-numpy

#using soapy sdr for remote device support?
# !sudo apt-get install -y soapysdr-module-remote # soapysdr-server
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# soapysdr-tools is already the newest version (0.6.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-soapysdr is already the newest version (0.6.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python3-soapysdr is already the newest version (0.6.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   soapysdr0.6-module-remote
# ...

# %%
# this loads a particularly prickly dependancy, tzdata, and configures it
# !TIMEZONE="America/Los_Angeles"   
#!sudo echo $TIMEZONE >> /etc/timezone                     
# !sudo cp -r /usr/share/zoneinfo/${TIMEZONE} /etc/localtime   # This sets the time
# !sudo apt install -y tzdata
# !sudo dpkg-reconfigure -f noninteractive tzdata
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tzdata is already the newest version (2018e-0ubuntu0.18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Sun Oct 14 15:36:24 UTC 2018.
# Universal Time is now:  Sun Oct 14 15:36:24 UTC 2018.

# %%
# so here we will get some modules: https://github.com/pothosware/PothosCore/wiki/Ubuntu
#hack rf support:
# !sudo apt install -y hackrf soapysdr-module-hackrf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# hackrf is already the newest version (2018.01.1-2).
# soapysdr-module-hackrf is already the newest version (0.3.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# ######################################################
# ## Soapy SDR -- the SDR abstraction library
# ######################################################
#
# Lib Version: v0.6.1-2
# API Version: v0.6.0
# ABI Version: v0.6
# Install root: /usr
# Search path: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/SoapySDR/modules0.6
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libHackRFSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libosmosdrSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libremoteSupport.so
# ...

# %%
#usrp support:
# !sudo apt install -y uhd-host uhd-soapysdr soapysdr-module-uhd
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# soapysdr-module-uhd is already the newest version (0.3.4-1build1).
# uhd-soapysdr is already the newest version (0.3.4-1build1).
# uhd-host is already the newest version (3.13.0.1-0ubuntu1~bionic1).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# ######################################################
# ## Soapy SDR -- the SDR abstraction library
# ######################################################
#
# Lib Version: v0.6.1-2
# API Version: v0.6.0
# ABI Version: v0.6
# Install root: /usr
# Search path: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/SoapySDR/modules0.6
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libHackRFSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libosmosdrSupport.so
# ...

# %%
#osmo sdr support:
# !sudo apt install -y osmo-sdr soapysdr-module-osmosdr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# osmo-sdr is already the newest version (0.1.8.effcaa7-7).
# soapysdr-module-osmosdr is already the newest version (0.2.5-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 66 not upgraded.
# ######################################################
# ## Soapy SDR -- the SDR abstraction library
# ######################################################
#
# Lib Version: v0.6.1-2
# API Version: v0.6.0
# ABI Version: v0.6
# Install root: /usr
# Search path: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/SoapySDR/modules0.6
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libHackRFSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libosmosdrSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libremoteSupport.so
# ...

# %%
#rtl sdr support:
# !sudo apt install -y rtl-sdr soapysdr-module-rtlsdr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   librtlsdr0 soapysdr0.6-module-rtlsdr
# The following NEW packages will be installed:
#   librtlsdr0 rtl-sdr soapysdr-module-rtlsdr soapysdr0.6-module-rtlsdr
# 0 upgraded, 4 newly installed, 0 to remove and 66 not upgraded.
# Need to get 122 kB of archives.
# After this operation, 414 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 soapysdr0.6-module-rtlsdr amd64 0.2.4-1 [34.5 kB]
# Get:2 http://ppa.launchpad.net/myriadrf/drivers/ubuntu bionic/main amd64 librtlsdr0 amd64 0.6.0-myriadrf1~bionic [29.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 soapysdr-module-rtlsdr amd64 0.2.4-1 [1,092 B]
# Get:4 http://ppa.launchpad.net/myriadrf/drivers/ubuntu bionic/main amd64 rtl-sdr amd64 0.6.0-myriadrf1~bionic [56.6 kB]
# Fetched 122 kB in 1s (102 kB/s)
# ...

# %%
#print information about the install
# !PothosUtil --system-info
# !SoapySDRUtil --info
# Out:
# ######################################################
# ## Soapy SDR -- the SDR abstraction library
# ######################################################
#
# Lib Version: v0.6.1-2
# API Version: v0.6.0
# ABI Version: v0.6
# Install root: /usr
# Search path: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/x86_64-linux-gnu/SoapySDR/modules0.6
# Search path: /usr/local/lib/SoapySDR/modules0.6
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libHackRFSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libosmosdrSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libremoteSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/librtlsdrSupport.so
# Module found: /usr/lib/x86_64-linux-gnu/SoapySDR/modules0.6/libuhdSupport.so
# Loading modules... linux; GNU C++ version 7.3.0; Boost_106501; UHD_003.010.003.000-0-unknown
#
# done
# ...

# %%
#import SoapySDR
import SoapySDR as s
from SoapySDR import * #SOAPY_SDR_ constants
import numpy #use numpy for buffers

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-592f42a061b0> in <module>()
# ----> 1 dict(s)
#
# TypeError: 'module' object is not iterable
